# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cbs_st = pd.read_csv('data/CBS/nodes-exp-cleaned.csv', names=['instance', 'nodes'])
# cbs_di = pd.read_csv('')
# icbs_st = pd.read_csv('')
# icbs_di = pd.read_csv('')

cbs_st
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_65124/2989626014.py in <module>
# ----> 1 cbs_st = pd.read_csv('data/CBS/nodes-exp-cleaned.csv', names=['instance', 'nodes'])
#       2 # cbs_di = pd.read_csv('')
#       3 # icbs_st = pd.read_csv('')
#       4 # icbs_di = pd.read_csv('')
#       5
#
# ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.local/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/CBS/nodes-exp-cleaned.csv'

# %% [markdown]
# sns.set_style("whitegrid")

# %%
plt.xticks(rotation=25)
plt.title('Number of Nodes Generated', fontsize=20)
plt.plot(cbs_st['instance'], cbs_st['nodes'],'b.', alpha=0.5, label='ratings')
# plt.plot(data['created_at'], data['prediction'], 'r-', linewidth=3,  label='prediction')
plt.legend()
plt.xlabel("Instances (custom)")
plt.ylabel("Number of nodes generated")
# plt.show()
plt.savefig('dog_rate_scpl.png')

# %%
generated = {'CBS + Standard': [300, 320, 330, 346, 370],
             'CBS + Disjoint': [280, 275, 250, 233, 200],
             'ICBS + Standard': [208, 206, 204, 202, 200],
             'ICBS + Disjoint': [180, 175, 166, 150, 130],
            } 

df = pd.DataFrame(generated, index=['instance_1','instance_2','instance_3','instance_4','instance_5'])

print(df)
# Out:
#             CBS + Standard  CBS + Disjoint  ICBS + Standard  ICBS + Disjoint
# instance_1             300             280              208              180
# instance_2             320             275              206              175
# instance_3             330             250              204              166
# instance_4             346             233              202              150
# instance_5             370             200              200              130

# %%
sns.set_style("whitegrid")
p = sns.lineplot(data=df, markers=True, palette='rocket_r')
p.set_xlabel("Instances (custom)", fontsize=14)
p.set_ylabel("Number of nodes generated", fontsize=14)
# Out:
# Text(0, 0.5, 'Number of nodes generated')

# %%
expanded = {'CBS + Standard': [100, 101, 120, 150, 165],
             'CBS + Disjoint': [80, 83, 90, 93, 97],
             'ICBS + Standard': [65, 70, 72, 73, 76],
             'ICBS + Disjoint': [50, 51, 52, 54, 58],
            } 

df2 = pd.DataFrame(expanded, index=['instance_1','instance_2','instance_3','instance_4','instance_5'])

print(df2)
# Out:
#             CBS + Standard  CBS + Disjoint  ICBS + Standard  ICBS + Disjoint
# instance_1             100              80               65               50
# instance_2             101              83               70               51
# instance_3             120              90               72               52
# instance_4             150              93               73               54
# instance_5             165              97               76               58

# %%
sns.set_style("whitegrid")
p2 = sns.lineplot(data=df2, markers=True, palette='rocket_r')
p2.set_xlabel("Instances (custom)", fontsize=14)
p2.set_ylabel("Number of nodes expanded", fontsize=14)
# Out:
# Text(0, 0.5, 'Number of nodes expanded')

# %%
# Replace with real numbers from batch test as lists with 50 elements, for 50 batch tests
batch_generated = {'CBS + Standard': np.random.randint(700, 1200, size=50),
                'CBS + Disjoint': np.random.randint(500, 1250, size=50),
                'ICBS + Standard': np.random.randint(570, 650, size=50),
                'ICBS + Disjoint': np.random.randint(300, 750, size=50),
                } 
df_batch_gen = pd.DataFrame(batch_generated)
print(df_batch_gen)
# Out:
#     CBS + Standard  CBS + Disjoint  ICBS + Standard  ICBS + Disjoint
# 0             1004            1070              636              333
# 1              746            1209              574              381
# 2              931            1056              646              598
# 3             1074            1061              643              522
# 4              731             623              637              585
# 5              839            1121              622              572
# 6             1132            1015              579              363
# 7             1164             789              618              354
# 8              739             565              641              310
# 9              835             535              646              421
# 10             717            1159              578              628
# 11            1163            1177              648              408
# 12            1077             841              574              656
# 13             773             807              574              521
# 14             915             968              649              661
# 15             856             815              582              688
# 16             773            1176              632              550
# 17            1160            1008              645              708
# 18             735             742              609              399
# 19             754             810              571              588
# 20             819             586              646              485
# 21             813             626              599              600
# 22            1010            1217              582              587
# 23             985             655              627              741
# 24             845             723              600              464
# 25            1023             654              596              601
# 26             762             623              603              371
# 27            1047             500              628              682
# 28            1188             689              574              623
# 29            1175             589              635              542
# 30            1021             905              588              530
# 31             752             828              616              303
# 32            1145             823              626              486
# 33            1007             710              612              621
# 34             966             541              644              478
# 35            1062             759              613              461
# 36             740            1002              642              484
# 37            1046            1157              629              648
# 38            1007             678              571              672
# 39             798            1177              642              361
# 40             897             702              646              437
# 41             722             531              571              528
# 42             924            1210              618              737
# 43             835             661              579              436
# 44             827             921              590              460
# 45            1143             697              608              383
# 46             931             832              645              575
# 47            1008             997              587              492
# 48             999            1148              583              676
# 49            1173             969              617              487

# %%
# Replace with real numbers from batch test as lists with 50 elements, for 50 batch tests
batch_expanded = {'CBS + Standard': np.random.randint(354, 800, size=50),
                'CBS + Disjoint': np.random.randint(300, 750, size=50),
                'ICBS + Standard': np.random.randint(280, 525, size=50),
                'ICBS + Disjoint': np.random.randint(150, 375, size=50),
                } 
df_batch_exp = pd.DataFrame(batch_expanded)
print(df_batch_exp)
# Out:
#     CBS + Standard  CBS + Disjoint  ICBS + Standard  ICBS + Disjoint
# 0              481             396              452              276
# 1              799             593              514              309
# 2              537             328              523              197
# 3              586             355              370              336
# 4              453             516              474              181
# 5              579             545              328              310
# 6              490             674              391              258
# 7              462             306              354              369
# 8              370             731              506              304
# 9              641             357              287              271
# 10             749             375              385              209
# 11             650             539              281              341
# 12             404             406              287              346
# 13             646             501              338              363
# 14             656             745              332              271
# 15             588             335              436              235
# 16             614             367              472              190
# 17             722             726              324              191
# 18             385             395              471              257
# 19             613             682              475              203
# 20             699             564              456              219
# 21             420             718              348              323
# 22             571             347              410              172
# 23             556             695              352              353
# 24             504             708              339              283
# 25             577             606              403              163
# 26             452             695              499              240
# 27             474             324              425              311
# 28             423             468              309              193
# 29             568             743              424              339
# 30             669             369              410              370
# 31             689             663              507              288
# 32             497             725              409              268
# 33             634             726              297              342
# 34             444             524              352              352
# 35             370             454              332              322
# 36             380             701              346              238
# 37             444             346              379              239
# 38             588             700              505              228
# 39             696             505              287              281
# 40             692             608              501              274
# 41             740             665              522              265
# 42             406             362              439              256
# 43             731             300              284              287
# 44             433             363              467              172
# 45             491             511              331              239
# 46             738             503              477              191
# 47             414             728              465              361
# 48             663             534              349              254
# 49             587             688              316              165

# %%
# For the batch

sns.set_style("whitegrid")
fig, ax = plt.subplots()

# Plot nodes generated
# sns.set_color_codes('pastel')
sns.barplot(data=df_batch_gen,
            label='Nodes generated', color='lightblue')

# Plot nodes expanded
# sns.set_color_codes('muted')
sns.barplot(data=df_batch_exp,
            label='Nodes expanded', color='black')
ax.set_ylabel('')

ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlabel='Average nodes generated and nodes expanded: batch test')
sns.despine(left=True, bottom=True)
# plt.savefig('ten_most_reviewed.png', bbox_inches='tight')
